# %%
#Let's see Indian Army Fan on Twitter ♥

# %%
#SDLC hehe...
from textblob import TextBlob
import sys
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import nltk
import pycountry
import re
import string
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from langdetect import detect
from nltk.stem import SnowballStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-81da53d636bd> in <module>()
#      17 from nltk.stem import SnowballStemmer
#      18 from nltk.sentiment.vader import SentimentIntensityAnalyzer
# ---> 19 from sklearn.feature_extraction.text import CountVectorizer
#
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\__init__.py in <module>()
#      55 else:
#      56     from . import __check_build
# ---> 57     from .base import clone
#      58     __check_build  # avoid flakes unused variable error
#      59
#
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\base.py in <module>()
# ...

# %%
#tweekeys
consumerKey = "x1hzO26uXe94C8ZNJh3JrMH0odel"
consumerSecret="del2cCDtxDIy4a2Vrdt4bpvly22vYZwqkArf6doNj7ZcLdB2glc9V"
accessToken= "748851880831250433-xJj12i1wHdDqJJ3Vmpgw0YL2i6nUSRedel"
accessTokenSecret= "dellPmVuO3Wh7ZJBGjQXpIZeaTLEmckJdRRZ1mCN0ZLu8i7a"
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken,accessTokenSecret)
api = tweepy.API(auth)

# %%
#getting top searched keywords detail
nltk.download('vader_lexicon')
def percentage(part,whole):
    return 100 * float(part)/float(whole)
keyword = input("Please enter keyword or hasing to search: ")
noOfTweet = int(input ("Please enter how many tweets to analyze: "))
tweets = tweepy.Cursor(api.search, q=keyword).items(noOfTweet)
positive =0
negative=0
neutral = 0
polarity =0
tweet_list =[]
neutral_list =[]
negative_list =[]
positive_list =[]
for tweet in tweets:
    print(tweet.text)
    tweet_list.append(tweet.text)
    analysis = TextBlob(tweet.text)
    score = SentimentIntensityAnalyzer().polarity_scores(tweet.text)
    neg = score['neg']
    neu = score['neu']
    pos  =score['pos']
    comp = score['compound']
    polarity += analysis.sentiment.polarity
    if neg > pos:
        negative_list.append(tweet.text)
        negative +=1
    elif pos > neg:
        positive +=1
    elif pos == neg:
        neutral_list.append(tweet.text)
        neutral += 1
positive = percentage(positive, noOfTweet)
negative = percentage(negative, noOfTweet)
neutral = percentage(neutral, noOfTweet)
polarity = percentage(polarity, noOfTweet)
positive = format(positive, '.1f')
negatitve = format(negative, '.1f')
neutral = format(neutral, '.1f')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\saurabh\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Please enter keyword or hasing to search: Indian Army
# Please enter how many tweets to analyze: 1000
# Jammu: Indian Army foils possible drone attacks on 2 military camps https://t.co/ZeUlrcxsRW
# RT @goonj: Reaching ration kits to the missed-out migrant workers of J&amp;K
# Continuing our ongoing partnership with the Indian Army in J&amp;K und…
# RT @Mahesh10816: Did you know in 1965 China accused Indian army for stealing 800 sheep and 59 Yaks in the Sikkim border area. China threate…
# RT @Mahesh10816: Did you know in 1965 China accused Indian army for stealing 800 sheep and 59 Yaks in the Sikkim border area. China threate…
# RT @rajnathsingh: Delighted to meet the brave and valiant soldiers of the Indian Army at Karu in Ladakh today. I salute their courage and f…
# ...

# %%
#numbers of tweets(Total, positive, Negetive, neutral)

tweet_list = pd.DataFrame(tweet_list)
neutral_list = pd.DataFrame(neutral_list)
negative_list=pd.DataFrame(negative_list)
positive_list=pd.DataFrame(positive_list)

print("total number: ",len(tweet_list))
print("positive number: ",len(positive_list))
print("negative number: ",len(negative_list))
print("neutral number: ",len(neutral_list))
# Out:
# total number:  1000
# positive number:  0
# negative number:  356
# neutral number:  192

# %%
#Creating PieCart
labels = ['Positive ['+str(positive)+'%]' , 'Neutral ['+str(neutral)+'%]','Negative ['+str(negative)+'%]']
sizes = [positive, neutral, negative]
colors = ['yellowgreen', 'blue','red']
patches, texts = plt.pie(sizes,colors=colors, startangle=90)
plt.style.use('default')
plt.legend(labels)
plt.title("Sentiment Analysis Result for keyword= "+keyword+"" )
plt.axis('equal')
plt.show()

# %%
tweet_list
# Out:
#                                                      0
# 0    Jammu: Indian Army foils possible drone attack...
# 1    RT @goonj: Reaching ration kits to the missed-...
# 2    RT @Mahesh10816: Did you know in 1965 China ac...
# 3    RT @Mahesh10816: Did you know in 1965 China ac...
# 4    RT @rajnathsingh: Delighted to meet the brave ...
# 5    RT @TheQuint: The Indian Army on 28 June, stat...
# 6    RT @rajnathsingh: Delighted to meet the brave ...
# 7    RT @goonj: Reaching ration kits to the missed-...
# 8    RT @SpokespersonMoD: Raksha Mantri Shri @rajna...
# 9    RT @rajnathsingh: Delighted to meet the brave ...
# 10   RT @ani_digital: Indian Army is capable of giv...
# 11   RT @rajnathsingh: Delighted to meet the brave ...
# 12   RT @ani_digital: Indian Army is capable of giv...
# 13   RT @drapr007: Reason behind Increase terror ac...
# 14   RT @drapr007: Reason behind Increase terror ac...
# 15   RT @drapr007: Reason behind Increase terror ac...
# ...

# %%
tweet_list.drop_duplicates(inplace =True)

# %%
#cleaning Text (RT, Punctuation etc)
#Creating new dataframe and new features

tw_list=pd.DataFrame(tweet_list)
tw_list["text"] = tw_list[0]
#Removing RT, Punction etc
remove_rt = lambda x: re.sub('RT @\w+: '," ",x)
rt =lambda x: re.sub("(@[A-Za-z0-9]+)|([[]-9A-Za-z \t])|(\w+:\/\/\S+)"," ",x)
tw_list["text"] = tw_list.text.map(remove_rt).map(rt)
tw_list["text"] = tw_list.text.str.lower()
tw_list.head(10)
# Out:
#                                                     0  \
# 0   Jammu: Indian Army foils possible drone attack...
# 1   RT @goonj: Reaching ration kits to the missed-...
# 2   RT @Mahesh10816: Did you know in 1965 China ac...
# 4   RT @rajnathsingh: Delighted to meet the brave ...
# 5   RT @TheQuint: The Indian Army on 28 June, stat...
# 8   RT @SpokespersonMoD: Raksha Mantri Shri @rajna...
# 10  RT @ani_digital: Indian Army is capable of giv...
# 13  RT @drapr007: Reason behind Increase terror ac...
# 16  RT @viral_fever_07: #restore_gahmar_trains\n @...
# 17  10th class student about covid pass mark sheet...
#
#                                                  text
# 0   jammu: indian army foils possible drone attack...
# 1    reaching ration kits to the missed-out migran...
# 2    did you know in 1965 china accused indian arm...
# 4    delighted to meet the brave and valiant soldi...
# 5    the indian army on 28 june, stated that a maj...
# ...

# %%
#Calculating Nagative, Positive, Neutral and Compound values
tw_list[['polarity', 'subjectivity']] = tw_list['text'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, row in tw_list['text'].iteritems():
    score = SentimentIntensityAnalyzer().polarity_scores(row)
    neg = score['neg']
    neu =score['neu']
    pos = score['pos']
    comp = score['compound']
    if neg> pos:
        tw_list.loc[index, 'sentiment'] = "negative"
    elif pos> neg:
        tw_list.loc[index, 'sentiment'] = "positive"
    else:
        tw_list.loc[index, 'sentiment'] = "neutral"
    tw_list.loc[index, 'neg'] = neg
    tw_list.loc[index, 'neu']= neu
    tw_list.loc[index, 'pos'] = pos
    tw_list.loc[index, 'compound']= comp
tw_list.head(10)
#compound is positive i guess
# Out:
#                                                     0  \
# 0   Jammu: Indian Army foils possible drone attack...
# 1   RT @goonj: Reaching ration kits to the missed-...
# 2   RT @Mahesh10816: Did you know in 1965 China ac...
# 4   RT @rajnathsingh: Delighted to meet the brave ...
# 5   RT @TheQuint: The Indian Army on 28 June, stat...
# 8   RT @SpokespersonMoD: Raksha Mantri Shri @rajna...
# 10  RT @ani_digital: Indian Army is capable of giv...
# 13  RT @drapr007: Reason behind Increase terror ac...
# 16  RT @viral_fever_07: #restore_gahmar_trains\n @...
# 17  10th class student about covid pass mark sheet...
#
#                                                  text  polarity  subjectivity  \
# 0   jammu: indian army foils possible drone attack...  -0.05000      0.550000
# 1    reaching ration kits to the missed-out migran...   0.00000      0.000000
# 2    did you know in 1965 china accused indian arm...   0.00000      0.000000
# ...

# %%
#creating new data frames for all sentiments(positive, negative and neutral)
tw_list_negative = tw_list[tw_list["sentiment"]=="negative"]
tw_list_positive = tw_list[tw_list["sentiment"]=="positive"]
tw_list_neutral = tw_list[tw_list["sentiment"]=="neutral"]

# %%
def count_values_in_column(data, feature):
    total=data.loc[:,feature].value_counts(dropna=False)
    percentage = round(data.loc[:,feature].value_counts(dropna=False,normalize=True)*100,2)
    return pd.concat([total,percentage],axis=1,keys=['Total','Percentage'])

#count values for sentiment
count_values_in_column(tw_list,"sentiment")
# Out:
#           Total  Percentage
# positive    127       38.60
# neutral     111       33.74
# negative     91       27.66

# %%
# create data for Pie Chart
pc = count_values_in_column(tw_list,"sentiment")
names= pc.index
size=pc["Percentage"]
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(size, labels=names, colors=['green','blue','red'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
#Function to create Wordcloud
from IPython.display import display
def create_wordcloud(text):
    mask = np.array(Image.open(r"C:\Users\saurabh\Desktop\BigDataAnalytics\cloud.png"))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color="white",
                   mask = mask,
                   max_words=3000,
                   stopwords=stopwords,
                   repeat=True)
    wc.generate(str(text))
    wc.to_file(r"C:\Users\saurabh\Desktop\BigDataAnalytics\wc.png")
    print("World Cloud Saved Successfully")
    path=r"C:\Users\saurabh\Desktop\BigDataAnalytics\wc.png"
    display(Image.open(path))

# %%
#!pip install IPython

# %%
#Creating wordcloud for all tweets
create_wordcloud(tw_list["text"].values)
# Out:
# World Cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=348x145 at 0x20A7D1DC438>

# %%
#Creating wordcloud for negative sentiment
create_wordcloud(tw_list_negative["text"].values)
# Out:
# World Cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=348x145 at 0x20A7CA1C0B8>

# %%
#Calculating tweet's length and word count
tw_list['text_len'] = tw_list['text'].astype(str).apply(len)
tw_list['text_word_count'] = tw_list['text'].apply(lambda x: len(str(x).split()))
round(pd.DataFrame(tw_list.groupby("sentiment").text_len.mean()),2)
# Out:
#            text_len
# sentiment
# negative     103.82
# neutral       87.29
# positive      97.46

# %%
tw_list
# Out:
#                                                      0  \
# 0    Jammu: Indian Army foils possible drone attack...
# 1    RT @goonj: Reaching ration kits to the missed-...
# 2    RT @Mahesh10816: Did you know in 1965 China ac...
# 4    RT @rajnathsingh: Delighted to meet the brave ...
# 5    RT @TheQuint: The Indian Army on 28 June, stat...
# 8    RT @SpokespersonMoD: Raksha Mantri Shri @rajna...
# 10   RT @ani_digital: Indian Army is capable of giv...
# 13   RT @drapr007: Reason behind Increase terror ac...
# 16   RT @viral_fever_07: #restore_gahmar_trains\n @...
# 17   10th class student about covid pass mark sheet...
# 18   RT @randm_indianguy: Mc Kode Aka Aditya Tiwari...
# 21   RT @The_skpandit: !!...BREAKING NEWS...!!\n\nभ...
# 23   @ANI And here we go to see new vacancy for the...
# 26   RT @MajorPoonia: This night of 1987, Captain B...
# 28   RT @nighat_abbas: Saviour of #Kashmir, Indian ...
# 31   @dpoignon My Harley didn’t have the back seat ...
# ...

# %%
tw_list.to_csv('tw_list.csv',index=False) 
#created ♥☻☺

# %%
#Thanks
